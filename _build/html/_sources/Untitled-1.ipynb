# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
grades = np.array([
    [4, 11,	2,	6,	23,],
    [6,	6,	8,	10,	30],
    [8,	7,	8,	18,	41],
    [4,	11,	1,	22,	38],
    [6,	12,	5,	15,	38],
    [5,	9,	8,	26,	48],
    [5,	11,	5,	18.5,	39.5],
    [4,	14,	3,	11,	32],
    [4,	8,	1,	13,	26],
    [6,	12,	3,	14,	35],
    [6,	7,	15,	21,	49],
    [6,	10,	5,	12,	33],
    [6,	12,	5,	14,	37],
    [8,	13,	15,	22,	58],
    [4,	11,	14,	16,	45],
    [4,	8,	0,	15,	27],
    [6,	5,	1,	11,	23],
    [4,	7,	5,	10,	26],
    [2,	8,	5,	9,	24],
    [4,	6,	5,	15,	30],
    [4,	6,	1,	9,	20],
    [4,	11,	2,	15,	32],
    [8,	11,	15,	13,	47],
    [6,	9,	16,	24,	55],
    [6,	6,	12,	23,	47],
    [4,	12,	0,	12,	28],
    [6,	11,	3,	21,	41],
    [4,	14,	16,	22,	56],
    [4,	9,	1,	16,	30],
    [4,	11,	16,	23,	54],
    [4,	7,	0,	16,	27],
    [2,	4,	3,	2,	11],
    [4,	5,	3,	12,	24],
    [8,	11,	16,	15,	50],
    [2,	10,	15,	14,	41],
    [6,	14,	5,	16,	41],
    [6,	11,	15,	9,	41],
    [2,	5,	2,	13,	22],
    [6,	14,	16,	22,	58],
    [8,	12,	16,	22,	58],
    [4,	0,	0,	11,	15],
    [4,	11,	1,	14,	30],
    [3,	11,	16,	22,	52],
    [4,	12,	3,	18,	37],
    [2,	6,	0,	16,	24],
    [4,	9,	2,	15,	30],
    [4,	11,	2,	12,	29],
    [8,	12,	3,	24,	47],
    [6,	14,	16,	24,	60],
    [6,	14,	16,	22,	58],
    [4,	9,	3,	6,	22],
    [2,	5,	5,	13,	25],
    [6,	7,	3,	16,	32],
    [6,	12,	3,	11,	32],
    [4,	10,	13,	15,	42],
    [5,	9,	2,	17,	33],
    [4,	11,	5,	14,	34],
    [6,	11,	5,	18,	40],
    [4,	9,	3,	12,	28],
    [6,	14,	5,	24,	49],
    [8,	12,	16,	22,	58],
    [4,	0,	3,	7.5, 14.5],
    [8,	13,	16,	19,	56],
    [8,	14,	15,	20,	57],
    [6,	12,	0,	18,	36],
    [8,	12,	15,	15,	50],
    [8,	12,	8,	13,	41],
    [4,	2,	2,	4,	12],
    [6,	6,	2,	6,	20],
    [6,	11,	3,	15,	35],
    [4,	12,	5,	19,	40],
    [6,	7,	1,	12,	26],
    [8,	13,	16,	18,	55],
    [4,	14,	0,	11,	29],
    [8,	13,	16,	24,	61],
    [6,	14,	5,	22,	47],
    [4,	14,	16,	18,	52],
    [6,	11,	8,	12,	37],
    [6,	11,	3,	18,	38],
    [8,	7,	4,	15,	34],
    [8,	9,	8,	18,	43],
    [6,	13,	14,	12,	45],
    [6,	12,	5,	21,	44],
    [2,	14,	5,	13,	34],
    [8,	14,	8,	22,	52],
    [8,	12,	5,	22,	47],
    [3,	8,	2,	16,	29],
    [6,	12,	5,	17,	40],
    [6,	8,	5,	11,	30],
    [6,	8,	5,	14,	33],
    [8,	9,	7,	16,	40],
    [4,	14,	14,	14,	46],
    [6,	13,	16,	24,	59],
    [4,	7,	3,	20,	34],
    [7,	14,	5,	18,	44],
    [4,	12,	16,	20,	52],
    [8,	8,	3,	13,	32],
    [6,	7,	3,	11,	27],
    [4,	10,	6,	11,	31],
    [0,	8,	2,	18,	28],
    [4,	11,	5,	24,	44],
    [6,	10,	3,	10,	29],
    [8,	14,	14,	21,	57],
    [6,	12,	15,	16,	49],
    [2,	12,	0,	19,	33],
    [6,	5,	5,	12,	28],
])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = grades[:, 0]

sns.histplot(data, bins=len(set(data)), discrete=True)
plt.xticks(sorted(list(set(data)))) # Set x-ticks explicitly if needed
plt.title('Problem 1')
plt.show()

# %%
data = grades[:, 1]

sns.histplot(data, bins=len(set(data)), discrete=True)
plt.xticks(sorted(list(set(data)))) # Set x-ticks explicitly if needed
plt.title('Problem 2')
plt.show()

# %%
data = grades[:, 2]

sns.histplot(data, bins=len(set(data)), discrete=True)
plt.xticks(sorted(list(set(data)))) # Set x-ticks explicitly if needed
plt.title('Problem 3')
plt.show()

# %%
data = grades[:, 3]
plt.figure(figsize=(20, 6)) # Optional: Adjust figure size for better visibility
sns.histplot(data, bins=len(set(data)), discrete=True)
plt.xticks(sorted(list(set(data)))) # Set x-ticks explicitly if needed
plt.title('Problem 4')
plt.show()

# %%
data = grades[:, 4]
plt.figure(figsize=(25, 6)) # Optional: Adjust figure size for better visibility
sns.histplot(data, bins=len(set(data)), discrete=True)
plt.xticks(sorted(list(set(data)))) # Set x-ticks explicitly if needed
plt.title('Total Score')
plt.show()
